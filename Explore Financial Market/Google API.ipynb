# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas.io.data as web
import datetime

# %%
start = datetime.datetime(2000, 1, 1)
end = datetime.datetime(2015, 6, 19)

# %%
#Nissan=web.DataReader(name='TYO:7201',data_source='google',start='2000-1-1')
Nikkei225=web.DataReader("^N225", 'yahoo', start, end)

# %%
LOreal_CAC40=web.DataReader("OR.PA", 'yahoo', start, end)

# %%
Morgan_Stanley.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3890 entries, 2000-01-03 00:00:00 to 2015-06-19 00:00:00
# Data columns (total 5 columns):
# Open      3890 non-null float64
# High      3890 non-null float64
# Low       3890 non-null float64
# Close     3890 non-null float64
# Volume    3890 non-null int64
# dtypes: float64(4), int64(1)

# %%
Morgan_Stanley['Close'].plot(figsize=(10,7))

# %%
Nikkei225.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2000-01-04 00:00:00 to 2015-06-19 00:00:00
# Data columns (total 6 columns):
# Open         3811 non-null float64
# High         3811 non-null float64
# Low          3811 non-null float64
# Close        3811 non-null float64
# Volume       3811 non-null int64
# Adj Close    3811 non-null float64
# dtypes: float64(5), int64(1)

# %%
Nikkei225['Close'].plot(figsize=(10,7))
