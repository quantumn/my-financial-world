# %%
import numpy as np
import pandas as pd
import pandas.io.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DAX=web.DataReader(name='^GDAXI',data_source='yahoo',start='2000-1-1')
DAX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3938 entries, 2000-01-03 00:00:00 to 2015-06-17 00:00:00
# Data columns (total 6 columns):
# Open         3938 non-null float64
# High         3938 non-null float64
# Low          3938 non-null float64
# Close        3938 non-null float64
# Volume       3938 non-null int64
# Adj Close    3938 non-null float64
# dtypes: float64(5), int64(1)

# %%
DAX['Close'].plot(figsize=(8,5))

# %%
# %%time
DAX['Ret_Loop']=0.0
for i in range(1,len(DAX)):
    DAX['Ret_Loop'][i]=np.log(DAX['Close'][i]/(DAX['Close'])[i-1])
# Out:
# CPU times: user 468 ms, sys: 32 ms, total: 500 ms
# Wall time: 477 ms

# %%
DAX[['Close','Ret_Loop']].tail()
# Out:
#                    Close  Ret_Loop
# Date
# 2015-06-11  11332.780273  0.005964
# 2015-06-12  11196.490234 -0.012099
# 2015-06-15  10984.969727 -0.019072
# 2015-06-16  11044.009766  0.005360
# 2015-06-17  10978.009766 -0.005994

# %%
# %time 
DAX['Return']=np.log(DAX['Close']/DAX['Close'].shift(1))
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 13.8 µs

# %%
DAX[['Close','Ret_Loop','Return']].tail()
# Out:
#                    Close  Ret_Loop    Return
# Date
# 2015-06-11  11332.780273  0.005964  0.005964
# 2015-06-12  11196.490234 -0.012099 -0.012099
# 2015-06-15  10984.969727 -0.019072 -0.019072
# 2015-06-16  11044.009766  0.005360  0.005360
# 2015-06-17  10978.009766 -0.005994 -0.005994

# %%
DAX[['Close','Return']].plot(subplots=True,style='b',figsize=(8,5))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0xacd4d72c>,
#        <matplotlib.axes.AxesSubplot object at 0xac2bf22c>], dtype=object)

# %%
DAX[['Close','Ret_Loop','Return']].plot(subplots=True,style='b',figsize=(8,5))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0xabf5c18c>,
#        <matplotlib.axes.AxesSubplot object at 0xabe8442c>,
#        <matplotlib.axes.AxesSubplot object at 0xabe3fcac>], dtype=object)

# %%
DAX['42d'] = pd.rolling_mean(DAX['Close'], window=42)
DAX['252d'] = pd.rolling_mean(DAX['Close'], window=252)

# %%
DAX[['Close','42d','252d']].tail()
# Out:
#                    Close           42d          252d
# Date
# 2015-06-11  11332.780273  11624.424293  10301.651619
# 2015-06-12  11196.490234  11597.228097  10306.598765
# 2015-06-15  10984.969727  11567.641671  10310.750628
# 2015-06-16  11044.009766  11539.371908  10315.239277
# 2015-06-17  10978.009766  11515.065941  10319.580663

# %%
DAX[['Close','42d','252d']].plot(figsize=(8,5))

# %%
import math
DAX['Mov_Vol']=pd.rolling_std(DAX['Return'],window=252)*math.sqrt(252)

# %%
DAX[['Close', 'Mov_Vol', 'Return']].plot(subplots=True, style='b',
                                         figsize=(8, 7))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0xabd581ec>,
#        <matplotlib.axes.AxesSubplot object at 0xabb4538c>,
#        <matplotlib.axes.AxesSubplot object at 0xabb8dbac>], dtype=object)
