# %%
import numpy as np
import pandas as pd
import pandas.io.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sp500=web.DataReader('^GSPC',data_source='yahoo',start='1/1/2000')

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3888 entries, 2000-01-03 00:00:00 to 2015-06-17 00:00:00
# Data columns (total 6 columns):
# Open         3888 non-null float64
# High         3888 non-null float64
# Low          3888 non-null float64
# Close        3888 non-null float64
# Volume       3888 non-null int64
# Adj Close    3888 non-null float64
# dtypes: float64(5), int64(1)

# %%
sp500['Close'].plot()

# %%
sp500['42d']=np.round(pd.rolling_mean(sp500['Close'],window=42),2)
sp500['252d']=np.round(pd.rolling_mean(sp500['Close'],window=252),2)

# %%
sp500[['Close','42d','252d',]].tail()
# Out:
#                   Close      42d     252d
# Date
# 2015-06-11  2108.860107  2106.60  2029.55
# 2015-06-12  2094.110107  2106.56  2030.20
# 2015-06-15  2084.429932  2106.03  2030.79
# 2015-06-16  2096.290039  2105.83  2031.41
# 2015-06-17  2100.439941  2106.29  2032.04

# %%
sp500[['Close','42d','252d',]].plot(grid=True,figsize=(8,5))

# %%
sp500['42-252'] = sp500['42d'] - sp500['252d']
sp500['42-252'].tail()
# Out:
# Date
# 2015-06-11    77.05
# 2015-06-12    76.36
# 2015-06-15    75.24
# 2015-06-16    74.42
# 2015-06-17    74.25
# Name: 42-252, dtype: float64

# %%
sp500['42-252'] = sp500['42d'] - sp500['252d']
sp500['42-252'].head()
# Out:
# Date
# 2000-01-03   NaN
# 2000-01-04   NaN
# 2000-01-05   NaN
# 2000-01-06   NaN
# 2000-01-07   NaN
# Name: 42-252, dtype: float64

# %%
SD=50
sp500['Regime']=np.where(sp500['42-252']>SD,1,0)
sp500['Regime']=np.where(sp500['42-252']<SD,-1,sp500['Regime'])
sp500['Regime'].value_counts()
# Out:
# -1    1852
#  1    1785
#  0     251
# dtype: int64

# %%
sp500['Regime'].plot(lw=0.5)
plt.ylim(
-1.1,1.1)
# Out:
# (-1.1, 1.1)

# %%
sp500['Market']=np.log(sp500['Close'] / sp500['Close'].shift(1))

# %%
sp500['Strategy']=sp500['Regime'].shift(1)*sp500['Market']

# %%
sp500[['Market','Strategy']].cumsum().apply(np.exp).plot(grid=True,figsize=(8,5))
